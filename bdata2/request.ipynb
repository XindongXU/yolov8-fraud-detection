# %%
# !pip install elasticsearch

from elasticsearch import Elasticsearch
from elasticsearch.helpers import scan
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from scipy.stats import linregress
from datetime import datetime, date, timedelta
from matplotlib import pyplot as plt
import seaborn as sns; sns.set()

# %%
#pip install elasticsearch-dsl

# %%
from elasticsearch import Elasticsearch
from elasticsearch import Elasticsearch
# from elasticsearch_dsl import Search, Q
from datetime import datetime, timedelta
def search_machines_by_date_and_message(login, password, message, interval):
    # Connection to Elasticsearch
    es = Elasticsearch(
        "https://wapp-gbg-elasticsearch-dev.azurewebsites.net:443/elastic/",
        http_auth=(login, password)
    )

    # Define the query
    query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "match": {
                            "message": message
                        }
                    },
                    {
                        "range": {
                            "createdAt": {
                                "gte": interval,
                                "format": "dd/MM/yyyy HH:mm:ss.SSS"
                            }
                        }
                    }
                ]
            }
        },
        "size": 1000  # You can adjust the size as needed
    }

    # Execute the query
    result = es.search(index="stream-reporting-machinealerts", body=query)
    print(result)
    print(1)
    # Extract machine serial numbers from the result
    machine_serial_numbers = [hit["_source"]["machineSerialNumber"] for hit in result["hits"]["hits"]]

    # Get unique machine serial numbers by converting the list to a set
    unique_machine_serial_numbers = set(machine_serial_numbers)

    # Calculate the unique machine count
    unique_machine_count = len(unique_machine_serial_numbers)

    return unique_machine_serial_numbers, unique_machine_count

# %%
# Example usage
login = "kamelia.a"
password = "azerty123"
message = "API : O1.2.9.1"
#interval = "now-8d/d"  
interval = "now-5w/w"
serial_numbers, count = search_machines_by_date_and_message(login, password, message, interval)

print("Unique Machine serial numbers with API version O1.2.9.1 from the last 7 days:", serial_numbers)
print("Number of unique machines:", count)
# Out:
# {'took': 4557, 'timed_out': False, '_shards': {'total': 57, 'successful': 57, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 10000, 'relation': 'gte'}, 'max_score': 17.974472, 'hits': [{'_index': 'stream-reporting-machinealerts-000017', '_type': '_doc', '_id': 'CDB9317CFD4C2C21EBD33BA6F0398758', '_score': 17.974472, '_source': {'alertType': 2, 'message': 'Starting machine n°00371. IHM : 3.3.0f6. API : O1.2.9.1. API Siemens : O1.2.9.1. 0', 'isActive': True, 'createdAt': '2023-07-31T13:29:28.3143730+02:00', 'id': 'CDB9317CFD4C2C21EBD33BA6F0398758', 'machineSerialNumber': '00371'}}, {'_index': 'stream-reporting-machinealerts-000018', '_type': '_doc', '_id': '83219AD581A3CBE0E93405ECAA58CDB6', '_score': 16.890316, '_source': {'alertType': 2, 'message': 'Starting machine n°00325. IHM : 3.3.1. API : O1.2.9.1. API Siemens : O1.2.9.1. 4', 'isActive': True, 'createdAt': '2023-08-14T08:05:43.9788010+02:00', 'id': '83219AD581A3CBE0E93405ECAA58CDB6', 'machineSerialNumber': '00325'}}, {'
# ...

# %%
from elasticsearch import Elasticsearch
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search, Q
from datetime import datetime, timedelta
def search_machines_by_date_and_message(login, password, message, interval):
    # Connection to Elasticsearch
    es = Elasticsearch(
        "https://wapp-gbg-elasticsearch-dev.azurewebsites.net:443/elastic/",
        http_auth=(login, password)
    )

    # Define the query
    query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "match": {
                            "message": message
                        }
                    },
                    {
                        "range": {
                            "createdAt": {
                                "gte": interval,
                                "format": "dd/MM/yyyy HH:mm:ss.SSS"
                            }
                        }
                    }
                ]
            }
        },
        "size": 1000  # You can adjust the size as needed
    }

    # Execute the query
    result = es.search(index="stream-reporting-machinealerts", body=query)
    print(result)
    # Extract machine serial numbers from the result
    machine_serial_numbers = [hit["_source"]["machineSerialNumber"] for hit in result["hits"]["hits"]]

    # Get unique machine serial numbers by converting the list to a set
    unique_machine_serial_numbers = set(machine_serial_numbers)

    # Calculate the unique machine count
    unique_machine_count = len(unique_machine_serial_numbers)

    return unique_machine_serial_numbers, unique_machine_count

# Example usage
login = "kamelia.a"
password = "azerty123"
message = "3.3.1"
interval = "now-3d/d"  # Example interval, adjust as needed

serial_numbers, count = search_machines_by_date_and_message(login, password, message, interval)

print("Unique Machine serial numbers with IHM version v3.3.1:", serial_numbers)
print("Number of unique machines:", count)
# Out:
# Unique Machine serial numbers with IHM version v3.3.1: {'00057', '00137', '00042', '00484', '00531', '00151', '00440', '00490', '00223', '00103', '00086', '00567', '00485', '00127', '00264', '00496', '00407', '00155', '00038', '00552', '00564', '00547', '00457', '00102', '00245', '00399', '00551', '00114', '00585', '00251', '00093', '00392', '00140', '00573', '00029', '00115', '00210', '00095', '00559', '00522', '00233', '00107', '00054', '00534', '00173', '00246', '00104', '00046', '00480', '00546', '00588', '00079', '00213', '00229', '00106', '00532', '00491', '00416', '00437', '00013', '00175', '00423', '00548', '00195', '00269', '00432', '00018', '00455', '00517', '00478', '00139', '00396', '00240', '00081', '00518', '00428', '00263', '00415', '00190', '00492', '00069', '00431', '00561', '00234', '00235', '00015', '00076', '00080', '00471', '00488', '00070', '00252', '00129', '00408', '00217', '00097', '00183', '00032', '00196', '00554', '00467', '00545', '00053', '00083', '00202
# ...

# %%
from elasticsearch import Elasticsearch

def get_all_machine_serial_numbers(login, password):
    # Connection to Elasticsearch
    es = Elasticsearch(
        "https://wapp-gbg-elasticsearch-dev.azurewebsites.net:443/elastic/",
        http_auth=(login, password)
    )

    # Define a simple match_all query
    query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "match": {
                            "message": message
                        }
                    },
                    {
                        "range": {
                            "createdAt": {
                                "gte": "now-1d/d",
                                "lte": "now",
                                "format": "dd/MM/yyyy HH:mm:ss.SSS"
                            }
                        }
                    }
                ]
            }
        },
        
        
        
        "size": 1000  # You can adjust the size as needed
    }

    # Execute the query
    result = es.search(index="stream-reporting-machinealerts", body=query)
    # Extract machine serial numbers from the result
    machine_serial_numbers = [hit["_source"]["machineSerialNumber"] for hit in result["hits"]["hits"]]

    # Get unique machine serial numbers by converting the list to a set
    unique_machine_serial_numbers = set(machine_serial_numbers)

    # Calculate the unique machine count
    unique_machine_count = len(unique_machine_serial_numbers)

    return unique_machine_serial_numbers, unique_machine_count

# Example usage
login = "kamelia.a"
password = "azerty123"

serial_numbers, count = get_all_machine_serial_numbers(login, password)

print("All Machine serial numbers:", serial_numbers)
print("Number of unique machines:", count)
# Out:
# All Machine serial numbers: {'00224', '00533', '00077', '00328', '00308', '00093', '00023', '00044', '00538', '00449', '00391', '00098', '00245', '00524', '00256', '00273', '00229', '00139', '00027', '00522', '00352', '00264', '00539', '00096', '00069', '00428', '00476', '00038', '00392', '00151', '00348', '00337', '00345', '00246', '00469', '00486', '00415', '00330', '00325', '00436', '00445', '00225', '00405', '00241', '00040', '00423', '00572', '00316', '00441', '00088', '00175', '00456', '00516', '00310', '00385', '00272', '00046', '00276', '00218', '00203', '00400', '00373', '00281', '00401', '00542', '00563', '00455', '00317', '00354', '00503', '00439', '00288', '00399', '00318', '00076', '00222', '00073', '00297', '00238', '00474', '00309', '00313', '00416', '00364', '00171', '00282', '00578', '00554', '00280', '00054', '00319', '00349', '00461', '00161', '00075', '00026', '00353', '00293', '00534', '00552', '00080', '00030', '00156', '00236', '00408', '12345', '00406', '00487
# ...

# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search, Q
from datetime import datetime, timedelta

def search_machines_by_date_and_message(login, password, message, interval):
    # Connection to Elasticsearch
    es = Elasticsearch(
        "https://wapp-gbg-elasticsearch-dev.azurewebsites.net:443/elastic/",
        http_auth=(login, password)
    )

    # Define the query to find machines that do not match the given message
    query = {
        "query": {
            "bool": {
                "must_not": [
                    {
                        "match": {
                            "message": message
                        }
                    }
                ],
                "filter": [
                    {
                        "range": {
                            "createdAt": {
                                "gte": interval,
                                "format": "dd/MM/yyyy HH:mm:ss.SSS"
                            }
                        }
                    }
                ]
            }
        },
        "size": 1000  # You can adjust the size as needed
    }

    # Execute the query
    result = es.search(index="stream-reporting-machinealerts", body=query)

    # Extract machine serial numbers from the result
    machine_serial_numbers = [hit["_source"]["machineSerialNumber"] for hit in result["hits"]["hits"]]

    # Get unique machine serial numbers by converting the list to a set
    unique_machine_serial_numbers = set(machine_serial_numbers)

    # Calculate the unique machine count
    unique_machine_count = len(unique_machine_serial_numbers)

    return unique_machine_serial_numbers, unique_machine_count

# Example usage
login = "kamelia.a"
password = "azerty123"
message = "API : O1.2.9.1"
interval = "now-1d/d"
serial_numbers, count = search_machines_by_date_and_message(login, password, message, interval)

print("Unique Machine serial numbers without the message 'O1.2.9.1' from the last 1 day:", serial_numbers)
print("Number of unique machines:", count)
# Out:
# Unique Machine serial numbers without the message 'O1.2.9.1' from the last 1 day: {'00319', '00377', '00200', '00175', '00241', '00498', '00448', '00194', '00349', '00546', '00327', '00185', '00025', '00378', '00081', '00213', '00530', '00149', '00533', '00346', '00225', '00260', '00552', '00450', '00538', '00571', '00454', '00521', '00293', '00593', '00028', '00139', '00126', '00518', '00562', '00130', '00417', '00264', '00221', '00406', '00550', '00079', '00536', '00345', '00196', '00147', '00422', '00036', '00251', '00314', '00353', '00179', '00117', '00539', '00409', '00309', '00589', '00522', '00124', '00203', '00295', '00516', '00463', '00118', '00526', '00298', '00568', '00174', '00096', '00534', '00492', '00325', '00496', '00487', '00211', '00204', '00323', '00022', '00046', '00412', '00407', '00091', '00013', '00366', '00388', '00477', '00097', '00542', '00566', '00318', '00035', '00414', '00023', '00501', '00445', '00154', '00083', '00430', '00338', '00102', '00074', '00303
# ...

# %%
from elasticsearch import Elasticsearch

def search_machines_by_api_version(login, password, api, interval):
    # Connection to Elasticsearch
    es = Elasticsearch(
        "https://wapp-gbg-elasticsearch-dev.azurewebsites.net:443/elastic/",
        http_auth=(login, password)
    )

    # Define the query
    query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "range": {
                            "createdAt": {
                                "gte": interval,
                                "format": "dd/MM/yyyy HH:mm:ss.SSS"
                            }
                        }
                    }
                ],
                "filter": [
                    {
                        "terms": {
                            "message": api
                        }
                    }
                ]
            }
        },
        "size": 1000  # You can adjust the size as needed
    }

    # Execute the query
    result = es.search(index="stream-reporting-machinealerts", body=query)

    # Extract machine serial numbers from the result
    machine_serial_numbers = [hit["_source"]["machineSerialNumber"] for hit in result["hits"]["hits"]]

    # Get unique machine serial numbers by converting the list to a set
    unique_machine_serial_numbers = set(machine_serial_numbers)

    # Calculate the unique machine count
    unique_machine_count = len(unique_machine_serial_numbers)

    return unique_machine_serial_numbers, unique_machine_count

# List of API versions you want to search for
api_versions = [
    "API : 2.0.4.4",
    "API : 2.0.4.5",
    "API : 2.0.8",
    "API : 2.0.8.1",
    "API : 2.0.8.4",
    "API : 2.0.8.4b",
    "API : 2.0.8.4d",
    "API : 2.0.8.5",
    "API : 2.0.8.5b-test",
    "API : 2.0.8.6",
    "API : 2.0.8.7",
    "API : 2.0.8.7c",
    "API : O1.2.9.0a",
    "API : O1.2.9.0b",
    "API : O1.2.9.1a",
    "API : O1.2.9.1b",
    "API : O1.2.9.1c",
    "API : O2.2.9.1",
    "API : O1.2.9.1",
]

login = "kamelia.a"
password = "azerty123"
interval = "now-1d/d"
for api in api_versions:
    serial_numbers, count = search_machines_by_api_version(login, password, api, interval)
    print("Unique Machine serial numbers with {} API version:".format(api), serial_numbers)
    print("Number of unique machines:", count)
# Out:
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# Cell In[15], line 77
#      75 interval = "now-1d/d"
#      76 for api in api_versions:
# ---> 77     serial_numbers, count = search_machines_by_api_version(login, password, api, interval)
#      78     print("Unique Machine serial numbers with {} API version:".format(api), serial_numbers)
#      79     print("Number of unique machines:", count)
#
# Cell In[15], line 37, in search_machines_by_api_version(login, password, api, interval)
#      11 query = {
#      12     "query": {
#      13         "bool": {
#    (...)
#      33     "size": 1000  # You can adjust the size as needed
#      34 }
#      36 # Execute the query
# ---> 37 result = es.search(index="stream-reporting-machinealerts", body=query)
#      39 # Extract machine serial numbers from the result
# ...

# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search, Q
from datetime import datetime, timedelta

def search_machines_by_date_and_message(login, password, api_version, interval):
    # Connection to Elasticsearch
    es = Elasticsearch(
        "https://wapp-gbg-elasticsearch-dev.azurewebsites.net:443/elastic/",
        http_auth=(login, password)
    )

    # Define the query
    query = {
        "query": {
            "bool": {
                "must": [
                    {
                        "match": {
                            "message": api_version
                        }
                    },
                    {
                        "match_phrase": {
                            "message": "Starting machine"
                        }
                    }
                ],
                "filter": [
                    {
                        "range": {
                            "createdAt": {
                                "gte": interval
                            }
                        }
                    }
                ]
            }
        },
        "size": 1000  # You can adjust the size as needed
    }

    # Execute the query
    result = es.search(index="stream-reporting-machinealerts", body=query)

    # Extract machine serial numbers from the result
    machine_serial_numbers = [hit["_source"]["machineSerialNumber"] for hit in result["hits"]["hits"]]

    # Get unique machine serial numbers by converting the list to a set
    unique_machine_serial_numbers = set(machine_serial_numbers)

    # Calculate the unique machine count
    unique_machine_count = len(unique_machine_serial_numbers)

    return unique_machine_serial_numbers, unique_machine_count

# List of API versions you want to search for
api_versions = [
    #"API : 2.0.4.4",
   # "API : 2.0.4.5",
    "API : O1.2.9.1"
]

login = "kamelia.a"
password = "azerty123"
interval = "now-1d/d"

for api in api_versions:
    print(api)
    serial_numbers, count = search_machines_by_date_and_message(login, password, api, interval)
    print("Unique Machine serial numbers from the last 1 day:", serial_numbers)
    print("Number of unique machines:", count)
# Out:
# API : O1.2.9.1
# ...
